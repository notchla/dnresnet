# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras import layers
from tensorflow.keras import initializers
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import tensorflow.keras.backend as K
import math
import pickle

# %%
y_train = np.load("/home/notchla/Documents/mias_y_train.npy", allow_pickle=True)
y_val = np.load("/home/notchla/Documents/mias_y_val.npy", allow_pickle=True)
x_train = np.load("/home/notchla/Documents/mias_x_train.npy", allow_pickle=True)
x_val = np.load("/home/notchla/Documents/mias_x_val.npy", allow_pickle=True)

print(np.max(y_train), np.max(y_val), np.max(x_train), np.max(x_val))
# Out:
# 1.0 0.9568628 1.0 1.0

# %%
plt.figure(figsize=(10,10))
plt.imshow(x_val[0])
plt.gray()

# %%
plt.figure(figsize=(10,10))
plt.imshow(y_val[0])
plt.gray()

# %%
y_val_tensor = tf.convert_to_tensor(y_val, dtype="float32")
grad_components = tf.image.sobel_edges(y_val_tensor)
grad_mag_components = grad_components**2
grad_mag_square = tf.math.reduce_sum(grad_mag_components, axis=-1)
grad_mag_img = tf.sqrt(grad_mag_square)
y_val_sobel = grad_mag_img.numpy()

y_val_sobel /= math.sqrt(32) #max possible value in the l2 sum of the 2 magnitudes

# %%
y_train_tensor = tf.convert_to_tensor(y_train, dtype="float32")
grad_components = tf.image.sobel_edges(y_train_tensor)
grad_mag_components = grad_components**2
grad_mag_square = tf.math.reduce_sum(grad_mag_components, axis=-1)
grad_mag_img = tf.sqrt(grad_mag_square)
y_train_sobel = grad_mag_img.numpy()

y_train_sobel /= math.sqrt(32)

# %%
print(np.max(y_train_sobel))
# Out:
# 0.706608

# %%
plt.figure(figsize=(10,10))
plt.imshow(y_val_sobel[0])
plt.gray()

# %%
#create patches
PATCHING_SIZE = 64
ksize_rows = PATCHING_SIZE
ksize_cols = PATCHING_SIZE
strides_rows = PATCHING_SIZE
strides_cols = PATCHING_SIZE
overlap = 8

ksizes = [1, ksize_rows, ksize_cols, 1]
strides = [1, strides_rows-overlap, strides_cols-overlap, 1]
rates = [1, 1, 1, 1]
padding = "VALID"

x_train_patches = tf.image.extract_patches(images = x_train, sizes = ksizes, strides = strides, rates=rates, padding=padding)
y_train_patches = tf.image.extract_patches(images = y_train, sizes = ksizes, strides = strides, rates=rates, padding=padding)
x_val_patches = tf.image.extract_patches(images = x_val, sizes = ksizes, strides = strides, rates=rates, padding=padding)
y_val_patches = tf.image.extract_patches(images = y_val, sizes = ksizes, strides = strides, rates=rates, padding=padding)
y_val_sobel_patches = tf.image.extract_patches(images = y_val_sobel, sizes = ksizes, strides = strides, rates=rates, padding=padding)
y_train_sobel_patches = tf.image.extract_patches(images = y_train_sobel, sizes = ksizes, strides = strides, rates=rates, padding=padding)

# %%
axis_0, axis_1, axis_2, _ = x_train_patches.shape
print(axis_0, axis_1, axis_2)
print(x_train_patches.shape)
# Out:
# 258 9 9
# (258, 9, 9, 4096)

# %%
IMAGES_TRAIN = axis_0

# %%
nsamples_train = axis_0*axis_1*axis_2
x_train_patches = np.reshape(x_train_patches, [nsamples_train, PATCHING_SIZE, PATCHING_SIZE, 1])
y_train_patches = np.reshape(y_train_patches, [nsamples_train, PATCHING_SIZE, PATCHING_SIZE, 1])
y_train_sobel_patches = np.reshape(y_train_sobel_patches, [nsamples_train, PATCHING_SIZE, PATCHING_SIZE, 1])

# %%
axis_0, axis_1, axis_2, _ = x_val_patches.shape
print(axis_0, axis_1, axis_2)
# Out:
# 64 9 9

# %%
IMAGES_VAL = axis_0

# %%
nsamples_train = axis_0*axis_1*axis_2;
x_val_patches = np.reshape(x_val_patches, [nsamples_train, PATCHING_SIZE, PATCHING_SIZE, 1])
y_val_patches = np.reshape(y_val_patches, [nsamples_train, PATCHING_SIZE, PATCHING_SIZE, 1])
y_val_sobel_patches = np.reshape(y_val_sobel_patches, [nsamples_train, PATCHING_SIZE, PATCHING_SIZE, 1])

# %%
del y_train
del x_train
del x_val
del y_val
del y_train_sobel
del y_val_sobel

# %%
n = 20
plt.figure(figsize=(20, 4))
for i in range(n):
  # display original
  ax = plt.subplot(2, n, i + 1)
  plt.imshow(y_train_patches[i], cmap="gray", vmin=0, vmax=1)
  plt.title("original")
  plt.gray()

  # display reconstruction
  ax = plt.subplot(2, n, i + 1 + n)
  plt.imshow(x_train_patches[i], cmap="gray", vmin=0, vmax=1)
  plt.title("original + noise")
  plt.gray()

# %%
img_height = 64
img_width = 64

# %%
class ResidualUnit(tf.keras.layers.Layer):
  def __init__(self, strides=1, activation="relu", **kwargs):
    super(ResidualUnit, self).__init__(**kwargs)
    self.activation = tf.keras.activations.get(activation)
    self.main_layers = [layers.Conv2D(32, (3,3), kernel_initializer=initializers.random_normal(stddev=0.001), padding="same"),
                        self.activation,
                        layers.Conv2D(32, (3,3), kernel_initializer=initializers.random_normal(stddev=0.001), padding="same")]
  def call(self, inputs):
    Z = inputs
    for layer in self.main_layers:
      Z = layer(Z)
    return inputs + Z
  def get_config(self):
    return {"resconv" : self.main_layers}

# %%
model = tf.keras.applications.ResNet50(include_top = False, input_shape = (64, 64, 3))
print(model.summary())
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 64, 64, 3)]  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 70, 70, 3)    0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 32, 32, 64)   9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 32, 32, 64)   256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 32, 32, 64)   0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 34, 34, 64)   0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 16, 16, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 16, 16, 64)   4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 16, 16, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 16, 16, 64)   36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 16, 16, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 16, 16, 256)  16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 16, 16, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 16, 16, 256)  1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 16, 16, 256)  1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 16, 16, 256)  0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 16, 16, 256)  0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 16, 16, 64)   16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 16, 16, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 16, 16, 64)   36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 16, 16, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 16, 16, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 16, 16, 256)  1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 16, 16, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 16, 16, 256)  0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 16, 16, 64)   16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 16, 16, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 16, 16, 64)   36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 16, 16, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 16, 16, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 16, 16, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 16, 16, 256)  1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 16, 16, 256)  0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 16, 16, 256)  0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 8, 8, 128)    32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 8, 8, 128)    0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 8, 8, 128)    147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 8, 8, 128)    0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 8, 8, 512)    131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 8, 8, 512)    66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 8, 8, 512)    2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 8, 8, 512)    2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 8, 8, 512)    0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 8, 8, 512)    0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 8, 8, 128)    65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 8, 8, 128)    0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 8, 8, 128)    147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 8, 8, 128)    0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 8, 8, 512)    66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 8, 8, 512)    2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 8, 8, 512)    0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 8, 8, 512)    0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 8, 8, 128)    65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 8, 8, 128)    0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 8, 8, 128)    147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 8, 8, 128)    0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 8, 8, 512)    66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 8, 8, 512)    2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 8, 8, 512)    0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 8, 8, 512)    0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 8, 8, 128)    65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 8, 8, 128)    0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 8, 8, 128)    147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 8, 8, 128)    512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 8, 8, 128)    0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 8, 8, 512)    66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 8, 8, 512)    2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 8, 8, 512)    0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 8, 8, 512)    0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 4, 4, 256)    131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 4, 4, 256)    0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 4, 4, 256)    590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 4, 4, 256)    0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 4, 4, 1024)   525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 4, 4, 1024)   263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 4, 4, 1024)   4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 4, 4, 1024)   4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 4, 4, 1024)   0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 4, 4, 1024)   0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 4, 4, 256)    262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 4, 4, 256)    0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 4, 4, 256)    590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 4, 4, 256)    0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 4, 4, 1024)   263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 4, 4, 1024)   4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 4, 4, 1024)   0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 4, 4, 1024)   0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 4, 4, 256)    262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 4, 4, 256)    0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 4, 4, 256)    590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 4, 4, 256)    0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 4, 4, 1024)   263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 4, 4, 1024)   4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 4, 4, 1024)   0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 4, 4, 1024)   0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 4, 4, 256)    262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 4, 4, 256)    0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 4, 4, 256)    590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 4, 4, 256)    0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 4, 4, 1024)   263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 4, 4, 1024)   4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 4, 4, 1024)   0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 4, 4, 1024)   0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 4, 4, 256)    262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 4, 4, 256)    0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 4, 4, 256)    590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 4, 4, 256)    0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 4, 4, 1024)   263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 4, 4, 1024)   4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 4, 4, 1024)   0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 4, 4, 1024)   0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 4, 4, 256)    262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 4, 4, 256)    0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 4, 4, 256)    590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 4, 4, 256)    1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 4, 4, 256)    0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 4, 4, 1024)   263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 4, 4, 1024)   4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 4, 4, 1024)   0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 4, 4, 1024)   0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 2, 2, 512)    524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 2, 2, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 2, 2, 512)    2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 2, 2, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 2, 2, 2048)   2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 2, 2, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 2, 2, 2048)   8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 2, 2, 2048)   8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 2, 2, 2048)   0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 2, 2, 2048)   0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 2, 2, 512)    1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 2, 2, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 2, 2, 512)    2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 2, 2, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 2, 2, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 2, 2, 2048)   8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 2, 2, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 2, 2, 2048)   0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 2, 2, 512)    1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 2, 2, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 2, 2, 512)    2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 2, 2, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 2, 2, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 2, 2, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 2, 2, 2048)   8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 2, 2, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 2, 2, 2048)   0           conv5_block3_add[0][0]
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 23,534,592
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
# None

# %%
feats = []
for layer in model.layers:
    if(layer.name[4] == "2"):
        layer1 = layer.output
    if(layer.name[4] == "3"):
        layer2 = layer.output
    if(layer.name[4] == "4"):
        layer3 = layer.output
    if(layer.name[4] == "5"):
        layer4 = layer.output

feats = [layer1, layer2, layer3, layer4]

# %%
activation_model = tf.keras.models.Model(inputs=model.input, outputs=feats)
print(activation_model)
# Out:
# <tensorflow.python.keras.engine.functional.Functional object at 0x7fc19c14e940>

# %%
class MyModel(tf.keras.Model):
  def __init__(self, residuals = 0):
    super(MyModel, self).__init__()
    self.conv1 = layers.Conv2D(64, (9,9), strides=1, kernel_initializer=initializers.random_normal(stddev=0.001), padding="same", name="conv1")
    self.conv2 = layers.Conv2D(32, (5,5), strides=1, kernel_initializer=initializers.random_normal(stddev=0.001), padding="same", name="conv2")
    self.conv3 = layers.Conv2D(1, (5,5), strides=1, kernel_initializer=initializers.random_normal(stddev=0.001), padding="same", name="conv3")
    self.residuals = [ResidualUnit() for i in range(residuals)]
  def call(self, inputs):
    x, edge = inputs
    x = self.conv1(x)
    x = self.conv2(x)
    for res in self.residuals:
      x = res(x)
    x = self.conv3(x)
    return x, edge*x, x
  #def model(self): #used to print model summary
   # x = tf.keras.layers.Input(shape=(64,64,1))
    #y = tf.keras.layers.Input(shape=(64, 64, 1))
    #return tf.keras.Model(inputs=[x, y], outputs=self.call([x,y]))
  def addResidual(self):
    self.residuals.append(ResidualUnit())
  def set_res_weights(self, weights):
    for weight, res in zip(weights, self.residuals):
      res.set_weights(weight)
  def inheritWeights(self,residuals):
    self.conv1.trainable = False
    self.conv2.trainable = False
    self.conv3.trainable = False
    for i in range(residuals):
      self.residuals[i].trainable = False
  def get_res_weights(self):
    tmp = []
    for res in self.residuals:
      tmp.append(res.get_weights())
    return tmp

# %%
mymodel = MyModel()
#mymodel.model().summary()

# %%
def perceptual_loss_function(y_true, y_pred):
    y_true_perceptual = tf.repeat(y_true, 3, -1)
    y_pred_perceptual = tf.repeat(y_pred, 3, -1)
    y_true_perceptual = activation_model(y_true_perceptual)
    y_pred_perceptual = activation_model(y_pred_perceptual)
    s = 0
    for i in range(4):
        mse = tf.keras.losses.MeanSquaredError()
        s += mse(y_true_perceptual[i], y_pred_perceptual[i])
    s = s/4
    return s

# %%
mymodel.compile(optimizer="adam", loss=[tf.keras.losses.MeanSquaredError(), tf.keras.losses.MeanSquaredError(), perceptual_loss_function], loss_weights=[0.5, 0.1, 0.01])

# %%
sobel_train = y_train_sobel_patches * y_train_patches
sobel_val = y_val_sobel_patches * y_val_patches

# %%
history = mymodel.fit([x_train_patches, y_train_sobel_patches], [y_train_patches, sobel_train, y_train_patches], epochs=10, shuffle=True, validation_data=([x_val_patches, y_val_sobel_patches], [y_val_patches, sobel_val, y_val_patches]))
# Out:
# Epoch 1/10
# 654/654 [==============================] - 47s 66ms/step - loss: 0.0050 - output_1_loss: 0.0100 - output_2_loss: 6.3253e-05 - output_3_loss: 0.0012 - val_loss: 1.5277e-04 - val_output_1_loss: 2.9957e-04 - val_output_2_loss: 1.7098e-05 - val_output_3_loss: 1.2787e-04
# Epoch 2/10
# 654/654 [==============================] - 42s 64ms/step - loss: 2.0992e-04 - output_1_loss: 4.1438e-04 - output_2_loss: 1.5247e-05 - output_3_loss: 1.2085e-04 - val_loss: 1.2236e-04 - val_output_1_loss: 2.4218e-04 - val_output_2_loss: 6.4970e-06 - val_output_3_loss: 6.2138e-05
# Epoch 3/10
# 654/654 [==============================] - 42s 64ms/step - loss: 1.1896e-04 - output_1_loss: 2.3522e-04 - output_2_loss: 6.4000e-06 - output_3_loss: 7.1082e-05 - val_loss: 2.0533e-04 - val_output_1_loss: 4.0854e-04 - val_output_2_loss: 4.5568e-06 - val_output_3_loss: 6.0543e-05
# Epoch 4/10
# 654/654 [==============================] - 42s 65ms/step - loss: 1.4374e-04 - output_1_loss: 2.8500e-04 - output_2_loss: 5.1480e-06 - output_3_loss: 7.2161e-05 - val_loss: 8.6798e-05 - val_output_1_loss: 1.7160e-04 - val_output_2_loss: 4.1889e-06 - val_output_3_loss: 5.8129e-05
# Epoch 5/10
# 654/654 [==============================] - 42s 64ms/step - loss: 8.6294e-05 - output_1_loss: 1.7025e-04 - output_2_loss: 4.8605e-06 - output_3_loss: 6.8401e-05 - val_loss: 9.5736e-05 - val_output_1_loss: 1.8953e-04 - val_output_2_loss: 3.8724e-06 - val_output_3_loss: 5.8462e-05
# Epoch 6/10
# 654/654 [==============================] - 42s 64ms/step - loss: 0.0222 - output_1_loss: 0.0443 - output_2_loss: 9.5678e-05 - output_3_loss: 9.1702e-04 - val_loss: 1.3780e-04 - val_output_1_loss: 2.7361e-04 - val_output_2_loss: 2.8195e-06 - val_output_3_loss: 7.1145e-05
# Epoch 7/10
# 654/654 [==============================] - 42s 65ms/step - loss: 1.1452e-04 - output_1_loss: 2.2723e-04 - output_2_loss: 3.0168e-06 - output_3_loss: 6.0367e-05 - val_loss: 1.0955e-04 - val_output_1_loss: 2.1739e-04 - val_output_2_loss: 2.8113e-06 - val_output_3_loss: 5.7189e-05
# Epoch 8/10
# 654/654 [==============================] - 42s 65ms/step - loss: 9.4057e-05 - output_1_loss: 1.8623e-04 - output_2_loss: 3.3939e-06 - output_3_loss: 6.0057e-05 - val_loss: 9.9139e-05 - val_output_1_loss: 1.9661e-04 - val_output_2_loss: 3.0726e-06 - val_output_3_loss: 5.2920e-05
# Epoch 9/10
# 654/654 [==============================] - 42s 65ms/step - loss: 8.5660e-05 - output_1_loss: 1.6936e-04 - output_2_loss: 3.7827e-06 - output_3_loss: 6.0124e-05 - val_loss: 9.4911e-05 - val_output_1_loss: 1.8809e-04 - val_output_2_loss: 3.3737e-06 - val_output_3_loss: 5.2703e-05
# Epoch 10/10
# 654/654 [==============================] - 42s 65ms/step - loss: 8.0435e-05 - output_1_loss: 1.5893e-04 - output_2_loss: 3.9112e-06 - output_3_loss: 5.8055e-05 - val_loss: 9.1751e-05 - val_output_1_loss: 1.8169e-04 - val_output_2_loss: 3.6208e-06 - val_output_3_loss: 5.4403e-05

# %%
with open("/home/notchla/Documents/history0", "wb") as file:
    pickle.dump(history.history, file)

# %%
res = []

# %%
def cascadeTraining(model, residuals, epochs):
    old_weights = model.get_weights()
    old_model = model
    for i in range(residuals):
        model.addResidual()
        model.inheritWeights(i)
        model.compile(optimizer="adam", loss=[tf.keras.losses.MeanSquaredError(), tf.keras.losses.MeanSquaredError(), perceptual_loss_function], loss_weights=[1, 0.1, 0.01])
        info = model.fit([x_train_patches, y_train_sobel_patches], [y_train_patches, sobel_train, y_train_patches], epochs=epochs, shuffle=True, validation_data=([x_val_patches, y_val_sobel_patches], [y_val_patches, sobel_val, y_val_patches]))
        res.append(model.get_res_weights())
        for layer in model.layers: print(layer.get_config())
        with open("/home/notchla/Documents/history" + str(i+1), "wb") as file:
            pickle.dump(info.history, file)

# %%
cascadeTraining(mymodel, 5, 10)
# Out:
# Epoch 1/10
# 654/654 [==============================] - 45s 64ms/step - loss: 1.3057e-04 - output_1_loss: 1.2980e-04 - output_2_loss: 2.9367e-06 - output_3_loss: 4.7717e-05 - val_loss: 1.0655e-04 - val_output_1_loss: 1.0600e-04 - val_output_2_loss: 1.6565e-06 - val_output_3_loss: 3.8156e-05
# Epoch 2/10
# 654/654 [==============================] - 41s 63ms/step - loss: 8.5601e-05 - output_1_loss: 8.5048e-05 - output_2_loss: 1.8035e-06 - output_3_loss: 3.7236e-05 - val_loss: 1.0123e-04 - val_output_1_loss: 1.0070e-04 - val_output_2_loss: 1.3466e-06 - val_output_3_loss: 4.0049e-05
# Epoch 3/10
# 654/654 [==============================] - 41s 62ms/step - loss: 8.0696e-05 - output_1_loss: 8.0179e-05 - output_2_loss: 1.5214e-06 - output_3_loss: 3.6501e-05 - val_loss: 1.1699e-04 - val_output_1_loss: 1.1655e-04 - val_output_2_loss: 1.2770e-06 - val_output_3_loss: 3.1739e-05
# Epoch 4/10
# 654/654 [==============================] - 41s 62ms/step - loss: 7.7722e-05 - output_1_loss: 7.7285e-05 - output_2_loss: 1.3822e-06 - output_3_loss: 2.9858e-05 - val_loss: 1.0581e-04 - val_output_1_loss: 1.0535e-04 - val_output_2_loss: 1.4407e-06 - val_output_3_loss: 3.1967e-05
# Epoch 5/10
# 654/654 [==============================] - 41s 62ms/step - loss: 7.5951e-05 - output_1_loss: 7.5512e-05 - output_2_loss: 1.3413e-06 - output_3_loss: 3.0560e-05 - val_loss: 1.0006e-04 - val_output_1_loss: 9.9682e-05 - val_output_2_loss: 1.0282e-06 - val_output_3_loss: 2.7262e-05
# Epoch 6/10
# 654/654 [==============================] - 41s 62ms/step - loss: 7.2206e-05 - output_1_loss: 7.1811e-05 - output_2_loss: 1.1815e-06 - output_3_loss: 2.7683e-05 - val_loss: 1.0711e-04 - val_output_1_loss: 1.0673e-04 - val_output_2_loss: 9.8600e-07 - val_output_3_loss: 2.7340e-05
# Epoch 7/10
# 654/654 [==============================] - 41s 62ms/step - loss: 7.2538e-05 - output_1_loss: 7.2150e-05 - output_2_loss: 1.1692e-06 - output_3_loss: 2.7158e-05 - val_loss: 9.3643e-05 - val_output_1_loss: 9.3275e-05 - val_output_2_loss: 1.0393e-06 - val_output_3_loss: 2.6398e-05
# Epoch 8/10
# 654/654 [==============================] - 41s 62ms/step - loss: 7.1942e-05 - output_1_loss: 7.1568e-05 - output_2_loss: 1.1105e-06 - output_3_loss: 2.6343e-05 - val_loss: 9.6751e-05 - val_output_1_loss: 9.6309e-05 - val_output_2_loss: 1.5799e-06 - val_output_3_loss: 2.8359e-05
# Epoch 9/10
# 654/654 [==============================] - 41s 62ms/step - loss: 7.1311e-05 - output_1_loss: 7.0932e-05 - output_2_loss: 1.1566e-06 - output_3_loss: 2.6408e-05 - val_loss: 9.4459e-05 - val_output_1_loss: 9.4115e-05 - val_output_2_loss: 9.6509e-07 - val_output_3_loss: 2.4716e-05
# Epoch 10/10
# 654/654 [==============================] - 41s 63ms/step - loss: 6.9667e-05 - output_1_loss: 6.9308e-05 - output_2_loss: 1.0903e-06 - output_3_loss: 2.4956e-05 - val_loss: 9.7259e-05 - val_output_1_loss: 9.6909e-05 - val_output_2_loss: 9.0978e-07 - val_output_3_loss: 2.5929e-05
# {'name': 'conv1', 'trainable': False, 'dtype': 'float32', 'filters': 64, 'kernel_size': (9, 9), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'RandomNormal', 'config': {'mean': 0.0, 'stddev': 0.001, 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# {'name': 'conv2', 'trainable': False, 'dtype': 'float32', 'filters': 32, 'kernel_size': (5, 5), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'RandomNormal', 'config': {'mean': 0.0, 'stddev': 0.001, 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# {'name': 'conv3', 'trainable': False, 'dtype': 'float32', 'filters': 1, 'kernel_size': (5, 5), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'RandomNormal', 'config': {'mean': 0.0, 'stddev': 0.001, 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# {'resconv': ListWrapper([<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc1da6b1700>, <function relu at 0x7fc1e00d9e50>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc1da9d82b0>])}
# Epoch 1/10
# 654/654 [==============================] - 46s 66ms/step - loss: 6.8839e-05 - output_1_loss: 6.8481e-05 - output_2_loss: 1.0174e-06 - output_3_loss: 2.5616e-05 - val_loss: 9.1781e-05 - val_output_1_loss: 9.1447e-05 - val_output_2_loss: 8.7361e-07 - val_output_3_loss: 2.4649e-05
# Epoch 2/10
# 654/654 [==============================] - 42s 64ms/step - loss: 6.7201e-05 - output_1_loss: 6.6871e-05 - output_2_loss: 9.8769e-07 - output_3_loss: 2.3080e-05 - val_loss: 9.3999e-05 - val_output_1_loss: 9.3674e-05 - val_output_2_loss: 8.5139e-07 - val_output_3_loss: 2.3983e-05
# Epoch 3/10
# 654/654 [==============================] - 42s 64ms/step - loss: 6.8401e-05 - output_1_loss: 6.8080e-05 - output_2_loss: 1.0012e-06 - output_3_loss: 2.2111e-05 - val_loss: 1.0011e-04 - val_output_1_loss: 9.9790e-05 - val_output_2_loss: 8.9591e-07 - val_output_3_loss: 2.3037e-05
# Epoch 4/10
# 654/654 [==============================] - 42s 64ms/step - loss: 6.7411e-05 - output_1_loss: 6.7090e-05 - output_2_loss: 9.6562e-07 - output_3_loss: 2.2437e-05 - val_loss: 1.0063e-04 - val_output_1_loss: 1.0033e-04 - val_output_2_loss: 8.2208e-07 - val_output_3_loss: 2.1968e-05
# Epoch 5/10
# 654/654 [==============================] - 42s 64ms/step - loss: 6.5994e-05 - output_1_loss: 6.5698e-05 - output_2_loss: 9.4315e-07 - output_3_loss: 2.0228e-05 - val_loss: 9.8106e-05 - val_output_1_loss: 9.7798e-05 - val_output_2_loss: 8.4995e-07 - val_output_3_loss: 2.2279e-05
# Epoch 6/10
# 654/654 [==============================] - 42s 64ms/step - loss: 6.6731e-05 - output_1_loss: 6.6435e-05 - output_2_loss: 8.9151e-07 - output_3_loss: 2.0733e-05 - val_loss: 9.7703e-05 - val_output_1_loss: 9.7416e-05 - val_output_2_loss: 8.1594e-07 - val_output_3_loss: 2.0496e-05
# Epoch 7/10
# 654/654 [==============================] - 42s 64ms/step - loss: 6.6876e-05 - output_1_loss: 6.6590e-05 - output_2_loss: 8.7042e-07 - output_3_loss: 1.9907e-05 - val_loss: 9.3824e-05 - val_output_1_loss: 9.3541e-05 - val_output_2_loss: 7.7142e-07 - val_output_3_loss: 2.0622e-05
# Epoch 8/10
# 654/654 [==============================] - 42s 64ms/step - loss: 6.5748e-05 - output_1_loss: 6.5474e-05 - output_2_loss: 8.2867e-07 - output_3_loss: 1.9150e-05 - val_loss: 9.8314e-05 - val_output_1_loss: 9.8026e-05 - val_output_2_loss: 7.5643e-07 - val_output_3_loss: 2.1234e-05
# Epoch 9/10
# 654/654 [==============================] - 42s 64ms/step - loss: 6.5374e-05 - output_1_loss: 6.5096e-05 - output_2_loss: 8.7485e-07 - output_3_loss: 1.9057e-05 - val_loss: 9.3803e-05 - val_output_1_loss: 9.3523e-05 - val_output_2_loss: 7.6701e-07 - val_output_3_loss: 2.0397e-05
# Epoch 10/10
# 654/654 [==============================] - 42s 64ms/step - loss: 6.5463e-05 - output_1_loss: 6.5194e-05 - output_2_loss: 8.3586e-07 - output_3_loss: 1.8545e-05 - val_loss: 9.8254e-05 - val_output_1_loss: 9.7973e-05 - val_output_2_loss: 7.5969e-07 - val_output_3_loss: 2.0521e-05
# {'name': 'conv1', 'trainable': False, 'dtype': 'float32', 'filters': 64, 'kernel_size': (9, 9), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'RandomNormal', 'config': {'mean': 0.0, 'stddev': 0.001, 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# {'name': 'conv2', 'trainable': False, 'dtype': 'float32', 'filters': 32, 'kernel_size': (5, 5), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'RandomNormal', 'config': {'mean': 0.0, 'stddev': 0.001, 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# {'name': 'conv3', 'trainable': False, 'dtype': 'float32', 'filters': 1, 'kernel_size': (5, 5), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'RandomNormal', 'config': {'mean': 0.0, 'stddev': 0.001, 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# {'resconv': ListWrapper([<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc1da6b1700>, <function relu at 0x7fc1e00d9e50>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc1da9d82b0>])}
# {'resconv': ListWrapper([<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc1afc1a640>, <function relu at 0x7fc1e00d9e50>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc1afc01ee0>])}
# Epoch 1/10
# 654/654 [==============================] - 47s 67ms/step - loss: 6.4160e-05 - output_1_loss: 6.3897e-05 - output_2_loss: 8.1227e-07 - output_3_loss: 1.8233e-05 - val_loss: 9.1849e-05 - val_output_1_loss: 9.1575e-05 - val_output_2_loss: 7.3313e-07 - val_output_3_loss: 2.0121e-05
# Epoch 2/10
# 654/654 [==============================] - 43s 65ms/step - loss: 6.6524e-05 - output_1_loss: 6.6258e-05 - output_2_loss: 8.0579e-07 - output_3_loss: 1.8611e-05 - val_loss: 9.5009e-05 - val_output_1_loss: 9.4737e-05 - val_output_2_loss: 7.2917e-07 - val_output_3_loss: 1.9855e-05
# Epoch 3/10
# 654/654 [==============================] - 43s 65ms/step - loss: 6.5638e-05 - output_1_loss: 6.5376e-05 - output_2_loss: 7.6825e-07 - output_3_loss: 1.8558e-05 - val_loss: 9.6362e-05 - val_output_1_loss: 9.6089e-05 - val_output_2_loss: 7.3705e-07 - val_output_3_loss: 1.9947e-05
# Epoch 4/10
# 654/654 [==============================] - 43s 65ms/step - loss: 6.4484e-05 - output_1_loss: 6.4223e-05 - output_2_loss: 8.0041e-07 - output_3_loss: 1.8127e-05 - val_loss: 9.4490e-05 - val_output_1_loss: 9.4226e-05 - val_output_2_loss: 7.2229e-07 - val_output_3_loss: 1.9162e-05
# Epoch 5/10
# 654/654 [==============================] - 43s 65ms/step - loss: 6.5752e-05 - output_1_loss: 6.5489e-05 - output_2_loss: 7.9032e-07 - output_3_loss: 1.8379e-05 - val_loss: 9.5241e-05 - val_output_1_loss: 9.4981e-05 - val_output_2_loss: 7.1203e-07 - val_output_3_loss: 1.8880e-05
# Epoch 6/10
# 654/654 [==============================] - 43s 65ms/step - loss: 6.5078e-05 - output_1_loss: 6.4812e-05 - output_2_loss: 7.9682e-07 - output_3_loss: 1.8581e-05 - val_loss: 9.3456e-05 - val_output_1_loss: 9.3202e-05 - val_output_2_loss: 7.1347e-07 - val_output_3_loss: 1.8247e-05
# Epoch 7/10
# 654/654 [==============================] - 43s 65ms/step - loss: 6.4109e-05 - output_1_loss: 6.3860e-05 - output_2_loss: 7.7305e-07 - output_3_loss: 1.7161e-05 - val_loss: 9.3196e-05 - val_output_1_loss: 9.2943e-05 - val_output_2_loss: 6.9465e-07 - val_output_3_loss: 1.8295e-05
# Epoch 8/10
# 654/654 [==============================] - 43s 65ms/step - loss: 6.5427e-05 - output_1_loss: 6.5178e-05 - output_2_loss: 7.5081e-07 - output_3_loss: 1.7409e-05 - val_loss: 1.0196e-04 - val_output_1_loss: 1.0171e-04 - val_output_2_loss: 7.1988e-07 - val_output_3_loss: 1.8285e-05
# Epoch 9/10
# 654/654 [==============================] - 43s 65ms/step - loss: 6.4899e-05 - output_1_loss: 6.4647e-05 - output_2_loss: 7.9332e-07 - output_3_loss: 1.7258e-05 - val_loss: 9.8426e-05 - val_output_1_loss: 9.8178e-05 - val_output_2_loss: 6.9832e-07 - val_output_3_loss: 1.7897e-05
# Epoch 10/10
# 654/654 [==============================] - 43s 65ms/step - loss: 6.4320e-05 - output_1_loss: 6.4098e-05 - output_2_loss: 6.5033e-07 - output_3_loss: 1.5682e-05 - val_loss: 9.5832e-05 - val_output_1_loss: 9.5585e-05 - val_output_2_loss: 6.8587e-07 - val_output_3_loss: 1.7897e-05
# {'name': 'conv1', 'trainable': False, 'dtype': 'float32', 'filters': 64, 'kernel_size': (9, 9), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'RandomNormal', 'config': {'mean': 0.0, 'stddev': 0.001, 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# {'name': 'conv2', 'trainable': False, 'dtype': 'float32', 'filters': 32, 'kernel_size': (5, 5), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'RandomNormal', 'config': {'mean': 0.0, 'stddev': 0.001, 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# {'name': 'conv3', 'trainable': False, 'dtype': 'float32', 'filters': 1, 'kernel_size': (5, 5), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'RandomNormal', 'config': {'mean': 0.0, 'stddev': 0.001, 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# {'resconv': ListWrapper([<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc1da6b1700>, <function relu at 0x7fc1e00d9e50>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc1da9d82b0>])}
# {'resconv': ListWrapper([<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc1afc1a640>, <function relu at 0x7fc1e00d9e50>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc1afc01ee0>])}
# {'resconv': ListWrapper([<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc1af933460>, <function relu at 0x7fc1e00d9e50>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc1adac54c0>])}
# Epoch 1/10
# 654/654 [==============================] - 48s 68ms/step - loss: 6.4118e-05 - output_1_loss: 6.3888e-05 - output_2_loss: 6.7829e-07 - output_3_loss: 1.6162e-05 - val_loss: 9.4348e-05 - val_output_1_loss: 9.4103e-05 - val_output_2_loss: 6.8832e-07 - val_output_3_loss: 1.7662e-05
# Epoch 2/10
# 654/654 [==============================] - 43s 67ms/step - loss: 6.3938e-05 - output_1_loss: 6.3704e-05 - output_2_loss: 7.4760e-07 - output_3_loss: 1.5883e-05 - val_loss: 9.1192e-05 - val_output_1_loss: 9.0949e-05 - val_output_2_loss: 6.7591e-07 - val_output_3_loss: 1.7570e-05
# Epoch 3/10
# 654/654 [==============================] - 43s 66ms/step - loss: 6.4693e-05 - output_1_loss: 6.4453e-05 - output_2_loss: 7.6138e-07 - output_3_loss: 1.6468e-05 - val_loss: 9.7167e-05 - val_output_1_loss: 9.6923e-05 - val_output_2_loss: 6.8816e-07 - val_output_3_loss: 1.7558e-05
# Epoch 4/10
# 654/654 [==============================] - 44s 67ms/step - loss: 6.4449e-05 - output_1_loss: 6.4218e-05 - output_2_loss: 6.9392e-07 - output_3_loss: 1.6118e-05 - val_loss: 9.6161e-05 - val_output_1_loss: 9.5915e-05 - val_output_2_loss: 6.8209e-07 - val_output_3_loss: 1.7786e-05
# Epoch 5/10
# 654/654 [==============================] - 44s 67ms/step - loss: 6.4693e-05 - output_1_loss: 6.4455e-05 - output_2_loss: 7.3744e-07 - output_3_loss: 1.6398e-05 - val_loss: 9.7024e-05 - val_output_1_loss: 9.6780e-05 - val_output_2_loss: 6.8558e-07 - val_output_3_loss: 1.7571e-05
# Epoch 6/10
# 654/654 [==============================] - 43s 67ms/step - loss: 6.4310e-05 - output_1_loss: 6.4082e-05 - output_2_loss: 6.8598e-07 - output_3_loss: 1.5936e-05 - val_loss: 9.8484e-05 - val_output_1_loss: 9.8239e-05 - val_output_2_loss: 6.7811e-07 - val_output_3_loss: 1.7702e-05
# Epoch 7/10
# 654/654 [==============================] - 44s 67ms/step - loss: 6.4500e-05 - output_1_loss: 6.4269e-05 - output_2_loss: 7.0965e-07 - output_3_loss: 1.6038e-05 - val_loss: 9.7114e-05 - val_output_1_loss: 9.6872e-05 - val_output_2_loss: 6.5832e-07 - val_output_3_loss: 1.7584e-05
# Epoch 8/10
# 654/654 [==============================] - 44s 67ms/step - loss: 6.5332e-05 - output_1_loss: 6.5104e-05 - output_2_loss: 6.9266e-07 - output_3_loss: 1.5898e-05 - val_loss: 9.8510e-05 - val_output_1_loss: 9.8272e-05 - val_output_2_loss: 6.6362e-07 - val_output_3_loss: 1.7245e-05
# Epoch 9/10
# 654/654 [==============================] - 44s 67ms/step - loss: 6.4375e-05 - output_1_loss: 6.4143e-05 - output_2_loss: 7.0101e-07 - output_3_loss: 1.6188e-05 - val_loss: 9.7544e-05 - val_output_1_loss: 9.7305e-05 - val_output_2_loss: 6.5392e-07 - val_output_3_loss: 1.7406e-05
# Epoch 10/10
# 654/654 [==============================] - 44s 67ms/step - loss: 6.3530e-05 - output_1_loss: 6.3316e-05 - output_2_loss: 6.3068e-07 - output_3_loss: 1.5088e-05 - val_loss: 9.4838e-05 - val_output_1_loss: 9.4604e-05 - val_output_2_loss: 6.4809e-07 - val_output_3_loss: 1.6910e-05
# {'name': 'conv1', 'trainable': False, 'dtype': 'float32', 'filters': 64, 'kernel_size': (9, 9), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'RandomNormal', 'config': {'mean': 0.0, 'stddev': 0.001, 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# {'name': 'conv2', 'trainable': False, 'dtype': 'float32', 'filters': 32, 'kernel_size': (5, 5), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'RandomNormal', 'config': {'mean': 0.0, 'stddev': 0.001, 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# {'name': 'conv3', 'trainable': False, 'dtype': 'float32', 'filters': 1, 'kernel_size': (5, 5), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'RandomNormal', 'config': {'mean': 0.0, 'stddev': 0.001, 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# {'resconv': ListWrapper([<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc1da6b1700>, <function relu at 0x7fc1e00d9e50>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc1da9d82b0>])}
# {'resconv': ListWrapper([<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc1afc1a640>, <function relu at 0x7fc1e00d9e50>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc1afc01ee0>])}
# {'resconv': ListWrapper([<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc1af933460>, <function relu at 0x7fc1e00d9e50>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc1adac54c0>])}
# {'resconv': ListWrapper([<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc1c06fc280>, <function relu at 0x7fc1e00d9e50>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc19ecb3ca0>])}
# Epoch 1/10
# 654/654 [==============================] - 49s 70ms/step - loss: 6.4559e-05 - output_1_loss: 6.4346e-05 - output_2_loss: 6.1984e-07 - output_3_loss: 1.5136e-05 - val_loss: 9.2766e-05 - val_output_1_loss: 9.2530e-05 - val_output_2_loss: 6.3957e-07 - val_output_3_loss: 1.7212e-05
# Epoch 2/10
# 654/654 [==============================] - 45s 68ms/step - loss: 6.3208e-05 - output_1_loss: 6.2987e-05 - output_2_loss: 6.6765e-07 - output_3_loss: 1.5460e-05 - val_loss: 9.3845e-05 - val_output_1_loss: 9.3612e-05 - val_output_2_loss: 6.3723e-07 - val_output_3_loss: 1.6991e-05
# Epoch 3/10
# 654/654 [==============================] - 45s 68ms/step - loss: 6.3792e-05 - output_1_loss: 6.3570e-05 - output_2_loss: 6.8290e-07 - output_3_loss: 1.5374e-05 - val_loss: 9.5819e-05 - val_output_1_loss: 9.5584e-05 - val_output_2_loss: 6.4090e-07 - val_output_3_loss: 1.7145e-05
# Epoch 4/10
# 654/654 [==============================] - 45s 68ms/step - loss: 6.3630e-05 - output_1_loss: 6.3413e-05 - output_2_loss: 6.4674e-07 - output_3_loss: 1.5163e-05 - val_loss: 9.0828e-05 - val_output_1_loss: 9.0593e-05 - val_output_2_loss: 6.3641e-07 - val_output_3_loss: 1.7097e-05
# Epoch 5/10
# 654/654 [==============================] - 45s 68ms/step - loss: 6.4482e-05 - output_1_loss: 6.4260e-05 - output_2_loss: 6.5062e-07 - output_3_loss: 1.5720e-05 - val_loss: 9.5380e-05 - val_output_1_loss: 9.5148e-05 - val_output_2_loss: 6.3523e-07 - val_output_3_loss: 1.6931e-05
# Epoch 6/10
# 654/654 [==============================] - 45s 68ms/step - loss: 6.3889e-05 - output_1_loss: 6.3664e-05 - output_2_loss: 7.0516e-07 - output_3_loss: 1.5502e-05 - val_loss: 9.8205e-05 - val_output_1_loss: 9.7971e-05 - val_output_2_loss: 6.4466e-07 - val_output_3_loss: 1.6998e-05
# Epoch 7/10
# 654/654 [==============================] - 45s 68ms/step - loss: 6.3623e-05 - output_1_loss: 6.3403e-05 - output_2_loss: 6.5519e-07 - output_3_loss: 1.5445e-05 - val_loss: 9.6207e-05 - val_output_1_loss: 9.5975e-05 - val_output_2_loss: 6.3276e-07 - val_output_3_loss: 1.6884e-05
# Epoch 8/10
# 654/654 [==============================] - 45s 68ms/step - loss: 6.4006e-05 - output_1_loss: 6.3781e-05 - output_2_loss: 6.8708e-07 - output_3_loss: 1.5659e-05 - val_loss: 9.8066e-05 - val_output_1_loss: 9.7831e-05 - val_output_2_loss: 6.4673e-07 - val_output_3_loss: 1.7070e-05
# Epoch 9/10
# 654/654 [==============================] - 45s 68ms/step - loss: 6.3809e-05 - output_1_loss: 6.3596e-05 - output_2_loss: 6.3204e-07 - output_3_loss: 1.5024e-05 - val_loss: 9.7343e-05 - val_output_1_loss: 9.7111e-05 - val_output_2_loss: 6.3038e-07 - val_output_3_loss: 1.6933e-05
# Epoch 10/10
# 654/654 [==============================] - 45s 68ms/step - loss: 6.3887e-05 - output_1_loss: 6.3673e-05 - output_2_loss: 6.1689e-07 - output_3_loss: 1.5252e-05 - val_loss: 9.7973e-05 - val_output_1_loss: 9.7739e-05 - val_output_2_loss: 6.4313e-07 - val_output_3_loss: 1.6915e-05
# {'name': 'conv1', 'trainable': False, 'dtype': 'float32', 'filters': 64, 'kernel_size': (9, 9), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'RandomNormal', 'config': {'mean': 0.0, 'stddev': 0.001, 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# {'name': 'conv2', 'trainable': False, 'dtype': 'float32', 'filters': 32, 'kernel_size': (5, 5), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'RandomNormal', 'config': {'mean': 0.0, 'stddev': 0.001, 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# {'name': 'conv3', 'trainable': False, 'dtype': 'float32', 'filters': 1, 'kernel_size': (5, 5), 'strides': (1, 1), 'padding': 'same', 'data_format': 'channels_last', 'dilation_rate': (1, 1), 'groups': 1, 'activation': 'linear', 'use_bias': True, 'kernel_initializer': {'class_name': 'RandomNormal', 'config': {'mean': 0.0, 'stddev': 0.001, 'seed': None}}, 'bias_initializer': {'class_name': 'Zeros', 'config': {}}, 'kernel_regularizer': None, 'bias_regularizer': None, 'activity_regularizer': None, 'kernel_constraint': None, 'bias_constraint': None}
# {'resconv': ListWrapper([<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc1da6b1700>, <function relu at 0x7fc1e00d9e50>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc1da9d82b0>])}
# {'resconv': ListWrapper([<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc1afc1a640>, <function relu at 0x7fc1e00d9e50>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc1afc01ee0>])}
# {'resconv': ListWrapper([<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc1af933460>, <function relu at 0x7fc1e00d9e50>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc1adac54c0>])}
# {'resconv': ListWrapper([<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc1c06fc280>, <function relu at 0x7fc1e00d9e50>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc19ecb3ca0>])}
# {'resconv': ListWrapper([<tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc1bca4bc70>, <function relu at 0x7fc1e00d9e50>, <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fc1a9771550>])}

# %%
decoded = mymodel((x_val_patches[:324], y_val_sobel_patches[:324]))

# %%
print(decoded[0].shape)
# Out:
# (324, 64, 64, 1)

# %%
print(np.max(decoded), np.min(decoded))
# Out:
# 1.0431775 -0.031711083

# %%
reconstructed = np.clip(decoded[0], a_min=0, a_max=1)

# %%
print(np.max(reconstructed), np.min(reconstructed))
# Out:
# 1.0 0.0

# %%
n = 10
plt.figure(figsize=(20, 10))
for i in range(n):

    # display original + noise
    ax = plt.subplot(3, n, i + 1)
    plt.title("original + noise")
    plt.imshow(x_val_patches[i], cmap="gray", vmin=0, vmax=1)
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    bx = plt.subplot(3, n, i + n + 1)
    plt.title("reconstructed")
    plt.imshow(reconstructed[i], cmap="gray", vmin=0, vmax=1)
    plt.gray()
    bx.get_xaxis().set_visible(False)
    bx.get_yaxis().set_visible(False)

    #display original
    bx = plt.subplot(3, n, i + 2*n + 1)
    plt.title("original")
    plt.imshow(y_val_patches[i], cmap="gray", vmin=0, vmax=1)
    plt.gray()
    bx.get_xaxis().set_visible(False)
    bx.get_yaxis().set_visible(False)

plt.show()

# %%
def reconstruct(patches, width, height, noriginal, dims, overlap):
    original = np.zeros((noriginal, width, height, dims))
    (npatches, pwidth, pheight, pchannel) = patches.shape
    nwidth = int(width / pwidth)
    nwidth = int(nwidth + nwidth*overlap/pwidth)
    nheight = int(height / pheight)
    nheight = int(nheight + nheight*overlap/pheight)
    for i in range(noriginal):
        for j in range(nheight):
            for k in range(nwidth):
                insert = patches[((j * nheight) + k)+(i*nwidth*nheight)]
                pixels = overlap // 2
                hstart = 2*(j-1) + 1
                hend = 2*j + 1
                wstart = 2*(k-1) + 1
                wend = 2*k + 1
                if(j == 0 and k == 0): #top left
                    insert = insert[:-pixels, :-pixels]
                    original[i, j*pheight:(j+1)*pheight - pixels, k*pwidth:(k+1)*pwidth - pixels] = insert
                elif(k == 0 and j == nheight - 1): #bottom left
                    insert = insert[pixels:, :-pixels]
                    original[i, j*pheight - hstart*pixels:(j+1)*pheight - 2*j*pixels, k*pwidth:(k+1)*pwidth - pixels] = insert
                elif(j == 0 and k == nwidth - 1): #top right 
                    insert = insert[:-pixels, pixels:]
                    original[i, j*pheight:(j+1)*pheight - pixels, k*pwidth - wstart*pixels: (k+1)*pwidth - 2*k*pixels] = insert
                elif(j == nheight - 1 and k == nwidth - 1):
                    insert = insert[pixels:, pixels:]
                    original[i, j*pheight - hstart*pixels: (j+1)*pheight - 2*j*pixels, k*pwidth - wstart*pixels: (k+1)*pwidth - 2*k*pixels] = insert
                elif(k == 0): #left border
                    insert = insert[pixels:-pixels, :-pixels]
                    original[i, j*pheight - hstart*pixels:(j+1)*pheight - hend*pixels, k*pwidth:(k+1)*pwidth - pixels] = insert
                elif(j == 0 ): #top border 
                    insert = insert[:-pixels, pixels:-pixels]
                    original[i, j*pheight:(j+1)*pheight - pixels, k*pwidth - wstart*pixels: (k+1)*pwidth - wend*pixels] = insert
                elif(k == nwidth - 1): #right border
                    insert = insert[pixels: -pixels, pixels:]
                    original[i, j*pheight - hstart*pixels : (j+1)*pheight - hend*pixels, k*pwidth - wstart*pixels: (k+1)*pwidth - 2*k*pixels] = insert
                elif(j == nheight - 1): #bottom border
                    insert = insert[pixels:, pixels:-pixels]
                    original[i, j*pheight - hstart*pixels:(j+1)*pheight - 2*j*pixels, k*pwidth - wstart*pixels: (k+1)*pwidth - wend*pixels] = insert
                else:
                    insert = insert[pixels:-pixels, pixels:-pixels]
                    original[i, j*pheight - hstart*pixels:(j+1)*pheight - hend*pixels, k*pwidth - wstart*pixels: (k+1)*pwidth - wend*pixels] = insert
                

    return original

# %%
y_val = reconstruct(y_val_patches, 512, 512, 64, 1, overlap)
x_val = reconstruct(x_val_patches, 512, 512, 64, 1, overlap)
x_train = reconstruct(x_train_patches, 512, 512, 258, 1, overlap)
y_train = reconstruct(y_train_patches, 512, 512, 258, 1, overlap)

recon = reconstruct(reconstructed, 512,512, 4,1, overlap)

# %%
recon.shape
# Out:
# (4, 512, 512, 1)

# %%
np.max(x_val)
# Out:
# 1.0

# %%
print(np.max(recon))
# Out:
# 1.0

# %%
plt.figure(figsize=(10,10))
plt.imshow(recon[3])
plt.gray()

# %%
plt.figure(figsize=(10,10))
plt.imshow(y_val[])
plt.gray()

# %%
plt.figure(figsize=(10,10))
plt.imshow(x_val[3])
plt.gray()

# %%
ssim = tf.image.ssim(y_val[:4], recon, max_val=1.0)
psnr = tf.image.psnr(y_val[:4], recon, max_val = 1.0)

# %%
print(ssim, psnr)
# Out:
# tf.Tensor([0.974366   0.97216517 0.9791596  0.9774392 ], shape=(4,), dtype=float32) tf.Tensor([39.770077 39.868492 42.35821  41.586823], shape=(4,), dtype=float32)

# %%
loss_list = []
def merge_history(nhistory):
    for i in range(nhistory + 1):
        with open("/home/notchla/Documents/history" + str(i), "rb") as file:
            while True:
                try:
                    loss_list.append(pickle.load(file))
                except EOFError:
                    break

# %%
merge_history(5)

# %%
loss_model = []
valloss_model = []
for loss in loss_list:
    loss_model += loss["loss"]
    valloss_model += loss["val_loss"]

# %%
plt.plot(loss_model, label="Training Loss")
plt.plot(valloss_model, label="Validation Loss")
plt.legend()

# %%
for i in range(len(res) - 1):
    for j, k in zip(res[i], res[i + 1]):
        for la, lb in zip(j, k):
            print(i, la.shape, lb.shape)
            np.testing.assert_allclose(la, lb)
# Out:
# 0 (3, 3, 32, 32) (3, 3, 32, 32)
# 0 (32,) (32,)
# 0 (3, 3, 32, 32) (3, 3, 32, 32)
# 0 (32,) (32,)
# 1 (3, 3, 32, 32) (3, 3, 32, 32)
# 1 (32,) (32,)
# 1 (3, 3, 32, 32) (3, 3, 32, 32)
# 1 (32,) (32,)
# 1 (3, 3, 32, 32) (3, 3, 32, 32)
# 1 (32,) (32,)
# 1 (3, 3, 32, 32) (3, 3, 32, 32)
# 1 (32,) (32,)
# 2 (3, 3, 32, 32) (3, 3, 32, 32)
# 2 (32,) (32,)
# 2 (3, 3, 32, 32) (3, 3, 32, 32)
# 2 (32,) (32,)
# 2 (3, 3, 32, 32) (3, 3, 32, 32)
# 2 (32,) (32,)
# 2 (3, 3, 32, 32) (3, 3, 32, 32)
# 2 (32,) (32,)
# 2 (3, 3, 32, 32) (3, 3, 32, 32)
# 2 (32,) (32,)
# 2 (3, 3, 32, 32) (3, 3, 32, 32)
# 2 (32,) (32,)
# 3 (3, 3, 32, 32) (3, 3, 32, 32)
# 3 (32,) (32,)
# 3 (3, 3, 32, 32) (3, 3, 32, 32)
# 3 (32,) (32,)
# 3 (3, 3, 32, 32) (3, 3, 32, 32)
# 3 (32,) (32,)
# 3 (3, 3, 32, 32) (3, 3, 32, 32)
# 3 (32,) (32,)
# 3 (3, 3, 32, 32) (3, 3, 32, 32)
# 3 (32,) (32,)
# 3 (3, 3, 32, 32) (3, 3, 32, 32)
# 3 (32,) (32,)
# 3 (3, 3, 32, 32) (3, 3, 32, 32)
# 3 (32,) (32,)
# 3 (3, 3, 32, 32) (3, 3, 32, 32)
# 3 (32,) (32,)
